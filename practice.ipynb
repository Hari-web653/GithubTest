# %% [markdown]
# <a href="https://colab.research.google.com/github/Hari-web653/GithubTest/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
import io

# %%
df = files.upload()
# Out:
#      <input type="file" id="files-a3b64ca8-e349-44b1-a24c-c3f784766165" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3b64ca8-e349-44b1-a24c-c3f784766165">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Superstore.csv to Superstore (1).csv

# %%
data = pd.read_csv(io.BytesIO(df['Superstore.csv']), encoding = 'unicode_escape')
data
# Out:
#       Row ID        Order ID  Order Date  ... Quantity Discount    Profit
# 0        1.0  CA-2013-152156  09-11-2013  ...      2.0     0.00   41.9136
# 1        2.0  CA-2013-152156  09-11-2013  ...      3.0     0.00  219.5820
# 2        3.0  CA-2013-138688  13-06-2013  ...      2.0     0.00    6.8714
# 3        4.0  US-2012-108966  11-10-2012  ...      5.0     0.45 -383.0310
# 4        5.0  US-2012-108966  11-10-2012  ...      2.0     0.20    2.5164
# ...      ...             ...         ...  ...      ...      ...       ...
# 9990  9991.0  CA-2014-121258  27-02-2014  ...      2.0     0.00   15.6332
# 9991  9992.0  CA-2014-121258  27-02-2014  ...      2.0     0.20   19.3932
# 9992  9993.0  CA-2014-121258  27-02-2014  ...      4.0     0.00   13.3200
# 9993     NaN             NaN         NaN  ...      NaN      NaN       NaN
# 9994  9994.0  CA-2014-119914  05-05-2014  ...      2.0     0.00   72.9480
#
# [9995 rows x 21 columns]

# %%
data.dropna(how = 'all',inplace = True)
data
# Out:
#       Row ID        Order ID  Order Date  ... Quantity Discount    Profit
# 0        1.0  CA-2013-152156  09-11-2013  ...      2.0     0.00   41.9136
# 1        2.0  CA-2013-152156  09-11-2013  ...      3.0     0.00  219.5820
# 2        3.0  CA-2013-138688  13-06-2013  ...      2.0     0.00    6.8714
# 3        4.0  US-2012-108966  11-10-2012  ...      5.0     0.45 -383.0310
# 4        5.0  US-2012-108966  11-10-2012  ...      2.0     0.20    2.5164
# ...      ...             ...         ...  ...      ...      ...       ...
# 9989  9990.0  CA-2011-110422  22-01-2011  ...      3.0     0.20    4.1028
# 9990  9991.0  CA-2014-121258  27-02-2014  ...      2.0     0.00   15.6332
# 9991  9992.0  CA-2014-121258  27-02-2014  ...      2.0     0.20   19.3932
# 9992  9993.0  CA-2014-121258  27-02-2014  ...      4.0     0.00   13.3200
# 9994  9994.0  CA-2014-119914  05-05-2014  ...      2.0     0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
data['Country'].unique()
# Out:
# array(['United States', 'USA'], dtype=object)

# %%
data['Country'].replace({'USA':'United States'}, inplace = True)

# %%
data['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
data[pd.isna(data['Sales'])]
# Out:
#     Row ID        Order ID  Order Date  ... Quantity Discount   Profit
# 14    15.0  US-2012-118983  22-11-2012  ...      5.0      0.8 -123.858
#
# [1 rows x 21 columns]

# %%
Mean = data['Sales'].mean()
Mean
# Out:
# 229.8741169118338

# %%
data['Sales'].fillna(value=Mean, inplace = True)
data
# Out:
#       Row ID        Order ID  Order Date  ... Quantity Discount    Profit
# 0        1.0  CA-2013-152156  09-11-2013  ...      2.0     0.00   41.9136
# 1        2.0  CA-2013-152156  09-11-2013  ...      3.0     0.00  219.5820
# 2        3.0  CA-2013-138688  13-06-2013  ...      2.0     0.00    6.8714
# 3        4.0  US-2012-108966  11-10-2012  ...      5.0     0.45 -383.0310
# 4        5.0  US-2012-108966  11-10-2012  ...      2.0     0.20    2.5164
# ...      ...             ...         ...  ...      ...      ...       ...
# 9989  9990.0  CA-2011-110422  22-01-2011  ...      3.0     0.20    4.1028
# 9990  9991.0  CA-2014-121258  27-02-2014  ...      2.0     0.00   15.6332
# 9991  9992.0  CA-2014-121258  27-02-2014  ...      2.0     0.20   19.3932
# 9992  9993.0  CA-2014-121258  27-02-2014  ...      4.0     0.00   13.3200
# 9994  9994.0  CA-2014-119914  05-05-2014  ...      2.0     0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
data.to_csv('Data Analyst')

# %%
files.download('Data Analyst')
